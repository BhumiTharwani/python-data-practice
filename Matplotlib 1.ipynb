# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
import numpy as np
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.xlabel('profit ')
plt.ylabel('sales')
plt.show()

# %%
x = [5, 2, 9, 4, 7] 
  
y = [10, 5, 8, 4, 2] 
  
plt.plot(x,y) 
  
plt.show()

# %% [markdown]
# # Formatting style

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'o') # try ro
plt.axis([0, 6, 0, 20])
plt.show()

# %%
t = np.arange(0., 5., 0.2)
t
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8])

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# # marker style

# %%
ypoints = np.array([2,4,3,6,5,8,7])

plt.plot(ypoints, marker = '*')  #try 0, + , |
plt.show()

# %%
#marker size

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
#marker border
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
#changing line style

plt.plot(ypoints, 'o:r') #try - , : , 
plt.show()

# %%
#line style
plt.plot(ypoints, linestyle = ':')
plt.show()

# %%
plt.plot(ypoints, linestyle = 'dashed')

# %%
#color
plt.plot(ypoints, color = 'r')  #hotpink
plt.show()

# %%
#width
plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %% [markdown]
# # subplot

# %%
x = np.array([2,4,3,6,4,8,7])
y = np.array([1,2,3,4,5,6,7])

plt.subplot(1, 2, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([2,4,6,8])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([2,4,3,6,4,8,7])
y = np.array([1,2,3,4,5,6,7])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([2,4,6,8])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([2,3,4,5])

plt.subplot(2, 2, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([2,5,3,7])

plt.subplot(2, 2, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 2, 3)
plt.plot(x,y)

x = np.array([11,12,10,13])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 4)
plt.plot(x,y)



#plt.show()

# %%
#Tiles
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("Title 1")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("Title 2")

plt.show()

# %%
#Main title
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([2,5,3,8])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("Title 1")

#plot 2:
x = np.array([0, 2,5,3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("Tile 2")

plt.suptitle("Main Title")
plt.show()

# %% [markdown]
# # Scatter plot

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11])
y = np.array([34,54,64,74,83,65,92,25,75,89])

plt.scatter(x, y)
plt.show()

# %%
#comparing 2 scatter plot
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# # Bar plot

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([2,4,6,8])

plt.bar(x,y)
plt.show()

# %%
x = ["USA", "INDIA"]
y = [121, 99]
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([8,6,4,2])

plt.barh(x, y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D","E"])
y = np.array([2,4,3,6,5])

plt.bar(x, y, color = "red")
plt.show()

# %%
x = np.array(["A", "B", "C", "D","E"])
y = np.array([2,4,3,6,5])

plt.bar(x, y, color = "hotpink")
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([2,4,6,8])

plt.bar(x, y, width = 0.3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([2,3,4,5])

plt.barh(x, y, height = 0.5)
plt.show()

# %% [markdown]
# # Histogram

# %% [markdown]
# ### A histogram is a plot that lets you discover, and show, the underlying frequency distribution (shape) of a set of continuous data. This allows the inspection of the data for its underlying distribution (e.g., normal distribution), outliers, skewness, etc.

# %%
x = np.random.normal(150,10, 250)##(mean,std,no.of elements/no.of values )
print(x)
plt.hist(x)
plt.show()
# Out:
# [124.1279709  165.3458441  154.34215102 161.58197639 152.12152319
#  157.96002483 133.11963586 133.84914777 152.76726292 156.19491001
#  145.70801363 153.7268822  170.56205374 148.22855229 145.23751172
#  163.42500881 153.02653924 135.78849132 150.94535238 128.52257578
#  178.34834411 155.75894499 158.47436147 143.05099124 142.0889107
#  163.56496248 148.93172702 145.01289086 164.81434891 153.4889839
#  129.52949602 142.0819562  150.84880663 143.71731313 147.36188421
#  154.1177458  150.30065154 137.03038225 145.02828495 147.39861354
#  170.7703932  152.95754425 163.95713723 148.34617624 141.89699587
#  153.41036968 152.30531259 154.39568689 151.58648554 159.7907385
#  146.19091632 166.57507456 169.46533127 147.43155431 153.65223133
#  147.76840007 130.88100896 154.92959523 155.74638426 148.55408198
#  166.43203544 159.45210167 157.50048579 141.42726878 153.27021694
#  146.48767987 160.61362043 148.56065309 145.21979108 141.20432692
#  153.03838141 160.18065314 147.20151642 151.60229908 159.94745715
#  157.67057298 129.74435051 152.22763272 154.7861009  148.84413484
#  167.10584115 165.03702496 157.40385708 146.10775256 130.71536429
#  156.2053325  158.29974936 155.91226026 150.06758341 153.35092669
#  147.30637796 152.09373302 156.50360762 151.73594558 164.34409215
#  154.7454005  142.36879858 153.09983736 132.13489026 138.48958591
#  134.49313251 143.1074132  145.88751469 150.85575789 142.48186771
#  136.67583149 146.1673879  161.13149032 163.46142831 151.22764533
#  149.44673883 162.65722225 148.1214678  151.3114911  143.10244754
#  150.3939074  150.85741195 151.9236217  168.62251566 160.80759707
#  144.18922648 165.86248748 152.33428327 150.14587335 135.05444497
#  136.95782941 152.15874495 140.03938076 157.31435729 153.03714262
#  159.34538165 138.71266209 149.78271859 156.46003719 133.17444142
#  145.43065736 139.35595949 133.7444167  137.2812423  137.44475155
#  146.54380623 155.00253144 155.11044707 167.52190015 156.1570662
#  159.59702919 158.88177228 167.31573405 128.58411991 151.03288023
#  153.631286   140.74043969 150.01305349 150.2929525  152.6916013
#  151.77058816 173.54498614 144.87604169 152.83273612 164.02393709
#  155.87862981 150.64806164 165.76510225 138.02710304 151.38337104
#  138.99412208 147.72971612 150.17112588 135.61966769 157.97985677
#  155.03424269 147.37496492 153.76585735 147.17948667 148.15608262
#  146.18965364 158.24332443 139.2794715  143.42448354 137.71011145
#  144.7722952  160.21368813 160.16347944 166.83257276 154.54686501
#  157.16807409 165.22672518 141.99430694 148.53707203 144.84621252
#  152.11825044 152.09357374 145.33647301 129.87706826 173.44641742
#  133.6984975  165.10681605 143.41843317 157.57189595 148.68977321
#  153.63327389 144.65874872 157.51681964 144.24186547 153.37828357
#  160.7733509  141.91710048 144.17238037 178.04507218 144.19097006
#  149.33900414 144.32413651 158.32090814 150.48815748 155.7606711
#  153.28001766 144.15159141 136.60631561 145.43110938 155.48745326
#  141.55253517 146.31423576 148.03033627 143.0147047  151.40806139
#  145.69160765 148.06521508 142.74213267 149.10297411 137.37626018
#  147.00053157 145.7247377  135.01183061 155.98580772 162.1398623
#  144.93550902 153.80560521 152.59456694 142.27830257 138.72089367
#  133.34529343 164.96884311 153.92321536 148.01676823 131.09659882
#  149.66077788 153.03021154 149.9922569  139.68654333 144.34172411]

# %%
x=np.random.normal(5,10,5)
x
# Out:
# array([24.16517188,  0.54921043,  4.89303224, 17.16426735,  9.66007859])

# %%
a= np.array([  1.5226432 ,  11.51112314, -19.01815825,   3.75094803,
        -5.63984207])

# %%
a.mean()
# Out:
# -1.57465719

# %%
x.mean()
# Out:
# 11.286352097160336

# %% [markdown]
# # Pia chart

# %%
y = np.array([20,35,10,45])

plt.pie(y)
plt.show()

# %%
#labels
y = np.array([20,35,10,45])
mylabels = ["USA", "India", "Russia", "China"]

plt.pie(y, labels=mylabels,autopct='%1.1f%%')  # autopct for show percentage
plt.show()

# %%
#angle set
plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
#explode
myexplode = [0, 0.2, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
#shoadow
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
#color
mycolors = ["black", "red", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
#legend
plt.pie(y, labels = mylabels)
plt.legend(loc="center left",bbox_to_anchor=(0.90,0.3)) #In the code bbox_to_anchor=(0.90,0.3),
#it means that the legend is positioned at 90% of the width of the bounding box (1) and at the vertical center (30%) 
#of the bounding box (0.3)
plt.show()

# %%
plt.pie(y, labels = mylabels)
plt.figlegend(loc='center right',title = 'Country')
plt.show()

# %%
#legend with title
plt.pie(y, labels = mylabels)
plt.figlegend(loc='center left',title = "Country")
plt.show()

# %% [markdown]
# # Boxplot

# %% [markdown]
# #### Boxplots are a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”).

# %%
np.random.seed(10) 
  
data_1 = np.random.normal(100, 10, 200) 
data_2 = np.random.normal(90, 20, 200) 
data_3 = np.random.normal(80, 30, 200) 
data_4 = np.random.normal(70, 40, 200) 
data = [data_1, data_2, data_3, data_4] 
  
fig = plt.figure(figsize =(10, 7)) 
  
# Creating axes instance 
ax = fig.add_axes([0, 0, 1, 1]) 
  
# Creating plot 
bp = ax.boxplot(data) 
  
# show plot 
plt.show()
